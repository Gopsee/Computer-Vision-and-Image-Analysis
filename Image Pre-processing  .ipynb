# %% [markdown]
# # Lab 1 - Pre-Processing Data
# ## Preparing the Image Data

# %%
# Source Folder and Train Folder
src_folder = "data/voc"
train_folder = "data/classification/training"

# %% [markdown]
# ## Explore the Images
# This code is to iterate through subfolders in the voc folder, and display the first image in each subfolder. Each subfolder represents a category, or class, of image.

# %%
import os
import shutil
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Required magic to display matplotlib plots in notebooks
# %matplotlib inline

# Set up a figure of an appropriate size
fig = plt.figure(figsize=(12, 16))

# loop through the subfolders
dir_num = 0
for root, folders, filenames in os.walk(src_folder):
    for folder in folders:
        # Load the first image file using the PIL library
        file = os.listdir(os.path.join(root,folder))[0]
        imgFile = os.path.join(root,folder, file)
        img = Image.open(imgFile)
        # Add the image to the figure (which will have 4 rows and enough columns to show a file from each folder)
        a=fig.add_subplot(4,np.ceil(len(folders)/4),dir_num + 1)
        imgplot = plt.imshow(img)
        # Add a caption with the folder name
        a.set_title(folder)
        dir_num = dir_num + 1

# %% [markdown]
# ## Standardize the Images
# The images vary in size and shape. Most machine learning techniques for computer vision work best when the image data is a consistent format and size. Preparing the data accordingly.

# %%
# Helper function to resize image
def resize_image(src_image, size=(128,128), bg_color="white"): 
    from PIL import Image, ImageOps 
    
    # resize the image so the longest dimension matches our target size
    src_image.thumbnail(size, Image.ANTIALIAS)
    
    # Create a new square background image
    new_image = Image.new("RGB", size, bg_color)
    
    # Paste the resized image into the center of the square background
    new_image.paste(src_image, (int((size[0] - src_image.size[0]) / 2), int((size[1] - src_image.size[1]) / 2)))
  
    # return the resized image
    return new_image


# Create resized copies of all of the source images
size = (128,128)

# Create the output folder if it doesn't already exist
if os.path.exists(train_folder):
    shutil.rmtree(train_folder)

# Loop through each subfolder in the input folder
for root, folders, files in os.walk(src_folder):
    for sub_folder in folders:
        print('processing folder ' + sub_folder)
        # Create a matching subfolder in the output dir
        saveFolder = os.path.join(train_folder,sub_folder)
        if not os.path.exists(saveFolder):
            os.makedirs(saveFolder)
        # Loop through the files in the subfolder
        file_names = os.listdir(os.path.join(root,sub_folder))
        for file_name in file_names:
            # Open the file
            file_path = os.path.join(root,sub_folder, file_name)
            print("reading " + file_path)
            image = Image.open(file_path)
            # Create a resized version and save it
            resized_image = resize_image(image, size)
            saveAs = os.path.join(saveFolder, file_name)
            print("writing " + saveAs)
            resized_image.save(saveAs)
# Out:
# processing folder automobile
# reading data/voc\automobile\000131.jpg
# writing data/classification/training\automobile\000131.jpg
# reading data/voc\automobile\000142.jpg
# writing data/classification/training\automobile\000142.jpg
# reading data/voc\automobile\000180.jpg
# writing data/classification/training\automobile\000180.jpg
# reading data/voc\automobile\000220.jpg
# writing data/classification/training\automobile\000220.jpg
# reading data/voc\automobile\000303.jpg
# writing data/classification/training\automobile\000303.jpg
# reading data/voc\automobile\000461.jpg
# writing data/classification/training\automobile\000461.jpg
# reading data/voc\automobile\000474.jpg
# writing data/classification/training\automobile\000474.jpg
# reading data/voc\automobile\000522.jpg
# writing data/classification/training\automobile\000522.jpg
# reading data/voc\automobile\000653.jpg
# writing data/classification/training\automobile\000653.jpg
# reading data/voc\automobile\000672.jpg
# writing data/classification/training\automobile\000672.jpg
# reading data/voc\automobile\000776.jpg
# writing data/classification/training\automobile\000776.jpg
# reading data/voc\automobile\000787.jpg
# writing data/classification/training\automobile\000787.jpg
# reading data/voc\automobile\000871.jpg
# writing data/classification/training\automobile\000871.jpg
# reading data/voc\automobile\000906.jpg
# writing data/classification/training\automobile\000906.jpg
# reading data/voc\automobile\001281.jpg
# writing data/classification/training\automobile\001281.jpg
# reading data/voc\automobile\001290.jpg
# writing data/classification/training\automobile\001290.jpg
# reading data/voc\automobile\001334.jpg
# writing data/classification/training\automobile\001334.jpg
# reading data/voc\automobile\001360.jpg
# writing data/classification/training\automobile\001360.jpg
# reading data/voc\automobile\001492.jpg
# writing data/classification/training\automobile\001492.jpg
# reading data/voc\automobile\001576.jpg
# writing data/classification/training\automobile\001576.jpg
# reading data/voc\automobile\001618.jpg
# writing data/classification/training\automobile\001618.jpg
# reading data/voc\automobile\001693.jpg
# writing data/classification/training\automobile\001693.jpg
# reading data/voc\automobile\001931.jpg
# writing data/classification/training\automobile\001931.jpg
# reading data/voc\automobile\002125.jpg
# writing data/classification/training\automobile\002125.jpg
# reading data/voc\automobile\002153.jpg
# writing data/classification/training\automobile\002153.jpg
# reading data/voc\automobile\002174.jpg
# writing data/classification/training\automobile\002174.jpg
# reading data/voc\automobile\002178.jpg
# writing data/classification/training\automobile\002178.jpg
# reading data/voc\automobile\002182.jpg
# writing data/classification/training\automobile\002182.jpg
# reading data/voc\automobile\002281.jpg
# writing data/classification/training\automobile\002281.jpg
# reading data/voc\automobile\002307.jpg
# writing data/classification/training\automobile\002307.jpg
# reading data/voc\automobile\002544.jpg
# writing data/classification/training\automobile\002544.jpg
# reading data/voc\automobile\002595.jpg
# writing data/classification/training\automobile\002595.jpg
# reading data/voc\automobile\002646.jpg
# writing data/classification/training\automobile\002646.jpg
# reading data/voc\automobile\002772.jpg
# writing data/classification/training\automobile\002772.jpg
# reading data/voc\automobile\002917.jpg
# writing data/classification/training\automobile\002917.jpg
# reading data/voc\automobile\003013.jpg
# writing data/classification/training\automobile\003013.jpg
# reading data/voc\automobile\003313.jpg
# writing data/classification/training\automobile\003313.jpg
# reading data/voc\automobile\003596.jpg
# writing data/classification/training\automobile\003596.jpg
# reading data/voc\automobile\003790.jpg
# writing data/classification/training\automobile\003790.jpg
# reading data/voc\automobile\003971.jpg
# writing data/classification/training\automobile\003971.jpg
# reading data/voc\automobile\004108.jpg
# writing data/classification/training\automobile\004108.jpg
# reading data/voc\automobile\004228.jpg
# writing data/classification/training\automobile\004228.jpg
# reading data/voc\automobile\004581.jpg
# writing data/classification/training\automobile\004581.jpg
# reading data/voc\automobile\004747.jpg
# writing data/classification/training\automobile\004747.jpg
# reading data/voc\automobile\004786.jpg
# writing data/classification/training\automobile\004786.jpg
# reading data/voc\automobile\004830.jpg
# writing data/classification/training\automobile\004830.jpg
# reading data/voc\automobile\004863.jpg
# writing data/classification/training\automobile\004863.jpg
# reading data/voc\automobile\004961.jpg
# writing data/classification/training\automobile\004961.jpg
# reading data/voc\automobile\005199.jpg
# writing data/classification/training\automobile\005199.jpg
# reading data/voc\automobile\005457.jpg
# writing data/classification/training\automobile\005457.jpg
# reading data/voc\automobile\005483.jpg
# writing data/classification/training\automobile\005483.jpg
# reading data/voc\automobile\005609.jpg
# writing data/classification/training\automobile\005609.jpg
# reading data/voc\automobile\005749.jpg
# writing data/classification/training\automobile\005749.jpg
# reading data/voc\automobile\005756.jpg
# writing data/classification/training\automobile\005756.jpg
# reading data/voc\automobile\005831.jpg
# writing data/classification/training\automobile\005831.jpg
# reading data/voc\automobile\005868.jpg
# writing data/classification/training\automobile\005868.jpg
# reading data/voc\automobile\006124.jpg
# writing data/classification/training\automobile\006124.jpg
# reading data/voc\automobile\006277.jpg
# writing data/classification/training\automobile\006277.jpg
# reading data/voc\automobile\006329.jpg
# writing data/classification/training\automobile\006329.jpg
# reading data/voc\automobile\006369.jpg
# writing data/classification/training\automobile\006369.jpg
# reading data/voc\automobile\006497.jpg
# writing data/classification/training\automobile\006497.jpg
# reading data/voc\automobile\006900.jpg
# writing data/classification/training\automobile\006900.jpg
# reading data/voc\automobile\006931.jpg
# writing data/classification/training\automobile\006931.jpg
# reading data/voc\automobile\007058.jpg
# writing data/classification/training\automobile\007058.jpg
# reading data/voc\automobile\007525.jpg
# writing data/classification/training\automobile\007525.jpg
# reading data/voc\automobile\007601.jpg
# writing data/classification/training\automobile\007601.jpg
# reading data/voc\automobile\007709.jpg
# writing data/classification/training\automobile\007709.jpg
# reading data/voc\automobile\007843.jpg
# writing data/classification/training\automobile\007843.jpg
# reading data/voc\automobile\008001.jpg
# writing data/classification/training\automobile\008001.jpg
# reading data/voc\automobile\008057.jpg
# writing data/classification/training\automobile\008057.jpg
# reading data/voc\automobile\008060.jpg
# writing data/classification/training\automobile\008060.jpg
# reading data/voc\automobile\008087.jpg
# writing data/classification/training\automobile\008087.jpg
# reading data/voc\automobile\008105.jpg
# writing data/classification/training\automobile\008105.jpg
# reading data/voc\automobile\008188.jpg
# writing data/classification/training\automobile\008188.jpg
# reading data/voc\automobile\008296.jpg
# writing data/classification/training\automobile\008296.jpg
# reading data/voc\automobile\008329.jpg
# writing data/classification/training\automobile\008329.jpg
# reading data/voc\automobile\008429.jpg
# writing data/classification/training\automobile\008429.jpg
# reading data/voc\automobile\008466.jpg
# writing data/classification/training\automobile\008466.jpg
# reading data/voc\automobile\008478.jpg
# writing data/classification/training\automobile\008478.jpg
# reading data/voc\automobile\008663.jpg
# writing data/classification/training\automobile\008663.jpg
# processing folder plane
# reading data/voc\plane\000033.jpg
# writing data/classification/training\plane\000033.jpg
# reading data/voc\plane\000117.jpg
# writing data/classification/training\plane\000117.jpg
# reading data/voc\plane\000228.jpg
# writing data/classification/training\plane\000228.jpg
# reading data/voc\plane\000256.jpg
# writing data/classification/training\plane\000256.jpg
# reading data/voc\plane\000325.jpg
# writing data/classification/training\plane\000325.jpg
# reading data/voc\plane\000431.jpg
# writing data/classification/training\plane\000431.jpg
# reading data/voc\plane\000610.jpg
# writing data/classification/training\plane\000610.jpg
# reading data/voc\plane\000730.jpg
# writing data/classification/training\plane\000730.jpg
# reading data/voc\plane\000738.jpg
# writing data/classification/training\plane\000738.jpg
# reading data/voc\plane\000763.jpg
# writing data/classification/training\plane\000763.jpg
# reading data/voc\plane\000815.jpg
# writing data/classification/training\plane\000815.jpg
# reading data/voc\plane\000845.jpg
# writing data/classification/training\plane\000845.jpg
# reading data/voc\plane\000896.jpg
# writing data/classification/training\plane\000896.jpg
# reading data/voc\plane\001107.jpg
# writing data/classification/training\plane\001107.jpg
# reading data/voc\plane\001144.jpg
# writing data/classification/training\plane\001144.jpg
# reading data/voc\plane\001270.jpg
# writing data/classification/training\plane\001270.jpg
# reading data/voc\plane\001288.jpg
# writing data/classification/training\plane\001288.jpg
# reading data/voc\plane\001545.jpg
# writing data/classification/training\plane\001545.jpg
# reading data/voc\plane\001708.jpg
# writing data/classification/training\plane\001708.jpg
# reading data/voc\plane\001858.jpg
# writing data/classification/training\plane\001858.jpg
# reading data/voc\plane\002255.jpg
# writing data/classification/training\plane\002255.jpg
# reading data/voc\plane\002266.jpg
# writing data/classification/training\plane\002266.jpg
# reading data/voc\plane\002279.jpg
# writing data/classification/training\plane\002279.jpg
# reading data/voc\plane\002348.jpg
# writing data/classification/training\plane\002348.jpg
# reading data/voc\plane\002354.jpg
# writing data/classification/training\plane\002354.jpg
# reading data/voc\plane\002376.jpg
# writing data/classification/training\plane\002376.jpg
# reading data/voc\plane\002439.jpg
# writing data/classification/training\plane\002439.jpg
# reading data/voc\plane\002737.jpg
# writing data/classification/training\plane\002737.jpg
# reading data/voc\plane\002847.jpg
# writing data/classification/training\plane\002847.jpg
# reading data/voc\plane\002869.jpg
# writing data/classification/training\plane\002869.jpg
# reading data/voc\plane\003133.jpg
# writing data/classification/training\plane\003133.jpg
# reading data/voc\plane\003493.jpg
# writing data/classification/training\plane\003493.jpg
# reading data/voc\plane\003554.jpg
# writing data/classification/training\plane\003554.jpg
# reading data/voc\plane\003667.jpg
# writing data/classification/training\plane\003667.jpg
# reading data/voc\plane\003886.jpg
# writing data/classification/training\plane\003886.jpg
# reading data/voc\plane\003993.jpg
# writing data/classification/training\plane\003993.jpg
# reading data/voc\plane\004009.jpg
# writing data/classification/training\plane\004009.jpg
# reading data/voc\plane\004052.jpg
# writing data/classification/training\plane\004052.jpg
# reading data/voc\plane\004135.jpg
# writing data/classification/training\plane\004135.jpg
# reading data/voc\plane\004196.jpg
# writing data/classification/training\plane\004196.jpg
# reading data/voc\plane\004286.jpg
# writing data/classification/training\plane\004286.jpg
# reading data/voc\plane\004390.jpg
# writing data/classification/training\plane\004390.jpg
# reading data/voc\plane\004470.jpg
# writing data/classification/training\plane\004470.jpg
# reading data/voc\plane\004643.jpg
# writing data/classification/training\plane\004643.jpg
# reading data/voc\plane\004982.jpg
# writing data/classification/training\plane\004982.jpg
# reading data/voc\plane\005079.jpg
# writing data/classification/training\plane\005079.jpg
# reading data/voc\plane\005391.jpg
# writing data/classification/training\plane\005391.jpg
# reading data/voc\plane\005393.jpg
# writing data/classification/training\plane\005393.jpg
# reading data/voc\plane\005487.jpg
# writing data/classification/training\plane\005487.jpg
# reading data/voc\plane\005620.jpg
# writing data/classification/training\plane\005620.jpg
# reading data/voc\plane\006025.jpg
# writing data/classification/training\plane\006025.jpg
# reading data/voc\plane\006129.jpg
# writing data/classification/training\plane\006129.jpg
# reading data/voc\plane\006349.jpg
# writing data/classification/training\plane\006349.jpg
# reading data/voc\plane\006350.jpg
# writing data/classification/training\plane\006350.jpg
# reading data/voc\plane\006374.jpg
# writing data/classification/training\plane\006374.jpg
# reading data/voc\plane\006773.jpg
# writing data/classification/training\plane\006773.jpg
# reading data/voc\plane\006794.jpg
# writing data/classification/training\plane\006794.jpg
# reading data/voc\plane\007088.jpg
# writing data/classification/training\plane\007088.jpg
# reading data/voc\plane\007274.jpg
# writing data/classification/training\plane\007274.jpg
# reading data/voc\plane\007297.jpg
# writing data/classification/training\plane\007297.jpg
# reading data/voc\plane\007820.jpg
# writing data/classification/training\plane\007820.jpg
# reading data/voc\plane\007916.jpg
# writing data/classification/training\plane\007916.jpg
# reading data/voc\plane\008107.jpg
# writing data/classification/training\plane\008107.jpg
# reading data/voc\plane\008275.jpg
# writing data/classification/training\plane\008275.jpg
# reading data/voc\plane\008372.jpg
# writing data/classification/training\plane\008372.jpg
# reading data/voc\plane\008450.jpg
# writing data/classification/training\plane\008450.jpg
# reading data/voc\plane\008472.jpg
# writing data/classification/training\plane\008472.jpg
# reading data/voc\plane\008667.jpg
# writing data/classification/training\plane\008667.jpg
# reading data/voc\plane\008723.jpg
# writing data/classification/training\plane\008723.jpg
# reading data/voc\plane\008847.jpg
# writing data/classification/training\plane\008847.jpg
# reading data/voc\plane\008905.jpg
# writing data/classification/training\plane\008905.jpg
# reading data/voc\plane\008971.jpg
# writing data/classification/training\plane\008971.jpg
# reading data/voc\plane\009085.jpg
# writing data/classification/training\plane\009085.jpg
# reading data/voc\plane\009272.jpg
# writing data/classification/training\plane\009272.jpg
# reading data/voc\plane\009394.jpg
# writing data/classification/training\plane\009394.jpg
# reading data/voc\plane\009476.jpg
# writing data/classification/training\plane\009476.jpg
# reading data/voc\plane\009615.jpg
# writing data/classification/training\plane\009615.jpg
# reading data/voc\plane\009681.jpg
# writing data/classification/training\plane\009681.jpg
# reading data/voc\plane\009905.jpg
# writing data/classification/training\plane\009905.jpg
# reading data/voc\plane\009911.jpg
# writing data/classification/training\plane\009911.jpg
# processing folder train
# reading data/voc\train\000095.jpg
# writing data/classification/training\train\000095.jpg
# reading data/voc\train\000635.jpg
# writing data/classification/training\train\000635.jpg
# reading data/voc\train\000675.jpg
# writing data/classification/training\train\000675.jpg
# reading data/voc\train\000712.jpg
# writing data/classification/training\train\000712.jpg
# reading data/voc\train\000791.jpg
# writing data/classification/training\train\000791.jpg
# reading data/voc\train\000831.jpg
# writing data/classification/training\train\000831.jpg
# reading data/voc\train\000863.jpg
# writing data/classification/training\train\000863.jpg
# reading data/voc\train\000899.jpg
# writing data/classification/training\train\000899.jpg
# reading data/voc\train\000946.jpg
# writing data/classification/training\train\000946.jpg
# reading data/voc\train\000966.jpg
# writing data/classification/training\train\000966.jpg
# reading data/voc\train\001221.jpg
# writing data/classification/training\train\001221.jpg
# reading data/voc\train\001383.jpg
# writing data/classification/training\train\001383.jpg
# reading data/voc\train\001483.jpg
# writing data/classification/training\train\001483.jpg
# reading data/voc\train\001565.jpg
# writing data/classification/training\train\001565.jpg
# reading data/voc\train\001907.jpg
# writing data/classification/training\train\001907.jpg
# reading data/voc\train\002054.jpg
# writing data/classification/training\train\002054.jpg
# reading data/voc\train\002166.jpg
# writing data/classification/training\train\002166.jpg
# reading data/voc\train\002180.jpg
# writing data/classification/training\train\002180.jpg
# reading data/voc\train\002214.jpg
# writing data/classification/training\train\002214.jpg
# reading data/voc\train\002321.jpg
# writing data/classification/training\train\002321.jpg
# reading data/voc\train\002502.jpg
# writing data/classification/training\train\002502.jpg
# reading data/voc\train\002600.jpg
# writing data/classification/training\train\002600.jpg
# reading data/voc\train\002757.jpg
# writing data/classification/training\train\002757.jpg
# reading data/voc\train\002844.jpg
# writing data/classification/training\train\002844.jpg
# reading data/voc\train\002891.jpg
# writing data/classification/training\train\002891.jpg
# reading data/voc\train\002906.jpg
# writing data/classification/training\train\002906.jpg
# reading data/voc\train\003038.jpg
# writing data/classification/training\train\003038.jpg
# reading data/voc\train\003370.jpg
# writing data/classification/training\train\003370.jpg
# reading data/voc\train\003417.jpg
# writing data/classification/training\train\003417.jpg
# reading data/voc\train\003464.jpg
# writing data/classification/training\train\003464.jpg
# reading data/voc\train\003497.jpg
# writing data/classification/training\train\003497.jpg
# reading data/voc\train\003499.jpg
# writing data/classification/training\train\003499.jpg
# reading data/voc\train\003564.jpg
# writing data/classification/training\train\003564.jpg
# reading data/voc\train\003605.jpg
# writing data/classification/training\train\003605.jpg
# reading data/voc\train\003628.jpg
# writing data/classification/training\train\003628.jpg
# reading data/voc\train\003866.jpg
# writing data/classification/training\train\003866.jpg
# reading data/voc\train\004102.jpg
# writing data/classification/training\train\004102.jpg
# reading data/voc\train\004315.jpg
# writing data/classification/training\train\004315.jpg
# reading data/voc\train\004354.jpg
# writing data/classification/training\train\004354.jpg
# reading data/voc\train\004411.jpg
# writing data/classification/training\train\004411.jpg
# reading data/voc\train\004436.jpg
# writing data/classification/training\train\004436.jpg
# reading data/voc\train\004437.jpg
# writing data/classification/training\train\004437.jpg
# reading data/voc\train\004776.jpg
# writing data/classification/training\train\004776.jpg
# reading data/voc\train\004911.jpg
# writing data/classification/training\train\004911.jpg
# reading data/voc\train\004951.jpg
# writing data/classification/training\train\004951.jpg
# reading data/voc\train\005267.jpg
# writing data/classification/training\train\005267.jpg
# reading data/voc\train\005269.jpg
# writing data/classification/training\train\005269.jpg
# reading data/voc\train\005355.jpg
# writing data/classification/training\train\005355.jpg
# reading data/voc\train\005384.jpg
# writing data/classification/training\train\005384.jpg
# reading data/voc\train\005389.jpg
# writing data/classification/training\train\005389.jpg
# reading data/voc\train\005654.jpg
# writing data/classification/training\train\005654.jpg
# reading data/voc\train\005685.jpg
# writing data/classification/training\train\005685.jpg
# reading data/voc\train\005995.jpg
# writing data/classification/training\train\005995.jpg
# reading data/voc\train\006107.jpg
# writing data/classification/training\train\006107.jpg
# reading data/voc\train\006344.jpg
# writing data/classification/training\train\006344.jpg
# reading data/voc\train\006377.jpg
# writing data/classification/training\train\006377.jpg
# reading data/voc\train\006400.jpg
# writing data/classification/training\train\006400.jpg
# reading data/voc\train\006466.jpg
# writing data/classification/training\train\006466.jpg
# reading data/voc\train\006499.jpg
# writing data/classification/training\train\006499.jpg
# reading data/voc\train\006538.jpg
# writing data/classification/training\train\006538.jpg
# reading data/voc\train\006652.jpg
# writing data/classification/training\train\006652.jpg
# reading data/voc\train\006670.jpg
# writing data/classification/training\train\006670.jpg
# reading data/voc\train\006943.jpg
# writing data/classification/training\train\006943.jpg
# reading data/voc\train\007123.jpg
# writing data/classification/training\train\007123.jpg
# reading data/voc\train\007168.jpg
# writing data/classification/training\train\007168.jpg
# reading data/voc\train\007666.jpg
# writing data/classification/training\train\007666.jpg
# reading data/voc\train\007742.jpg
# writing data/classification/training\train\007742.jpg
# reading data/voc\train\008235.jpg
# writing data/classification/training\train\008235.jpg
# reading data/voc\train\008244.jpg
# writing data/classification/training\train\008244.jpg
# reading data/voc\train\008295.jpg
# writing data/classification/training\train\008295.jpg
# reading data/voc\train\008506.jpg
# writing data/classification/training\train\008506.jpg
# reading data/voc\train\008553.jpg
# writing data/classification/training\train\008553.jpg
# reading data/voc\train\008710.jpg
# writing data/classification/training\train\008710.jpg
# reading data/voc\train\008766.jpg
# writing data/classification/training\train\008766.jpg
# reading data/voc\train\009187.jpg
# writing data/classification/training\train\009187.jpg
# reading data/voc\train\009254.jpg
# writing data/classification/training\train\009254.jpg
# reading data/voc\train\009377.jpg
# writing data/classification/training\train\009377.jpg
# reading data/voc\train\009401.jpg
# writing data/classification/training\train\009401.jpg
# reading data/voc\train\009855.jpg
# writing data/classification/training\train\009855.jpg
# reading data/voc\train\009860.jpg
# writing data/classification/training\train\009860.jpg

# %% [markdown]
# ## Compare the Original and Resized Images
# This code will output the original and resized version of the first image in each subfolder.

# %%
# Create a new figure
fig = plt.figure(figsize=(12,12))

# loop through the subfolders in the input directory
image_num = 0
for root, folders, filenames in os.walk(src_folder):
    for folder in folders:
        # Get the first image in the subfolder and add it to a plot that has two columns and row for each folder
        file = os.listdir(os.path.join(root,folder))[0]
        src_file = os.path.join(src_folder,folder, file)
        src_image = Image.open(src_file)
        image_num += 1
        a=fig.add_subplot(len(folders), 2, image_num)
        imgplot = plt.imshow(src_image)
        a.set_title(folder)
        # The next image is the resized counterpart - load and plot it
        resized_file = os.path.join(train_folder,folder, file)
        resized_image = Image.open(resized_file)
        image_num += 1
        b=fig.add_subplot(len(folders), 2, image_num)
        imgplot = plt.imshow(resized_image)
        b.set_title('resized ' + folder)
